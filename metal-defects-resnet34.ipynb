bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_257.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_212.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_93.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_161.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_66.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_271.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_195.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_64.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_29.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_56.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_50.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_210.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_274.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_300.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_251.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_262.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_295.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_45.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_6.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_171.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_264.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_40.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_299.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_146.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_196.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_276.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_83.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_44.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_33.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_20.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_7.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_70.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_159.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_233.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_140.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_123.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_127.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_88.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_16.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_168.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_199.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_57.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_255.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_243.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_269.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_4.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_194.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_206.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_86.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_242.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Inclusion/In_135.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_79.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_227.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_232.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_186.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_233.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_82.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_207.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_157.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_15.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_284.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_125.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_33.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_265.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_169.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_35.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_224.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_196.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_293.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_172.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_264.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_3.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_240.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_122.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_237.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_140.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_300.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_7.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_123.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_17.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_13.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_214.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_289.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_230.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_2.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_68.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_215.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_158.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_153.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_191.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_209.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_163.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_54.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_61.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_256.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_24.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_171.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_296.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_234.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_48.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_258.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Rolled/RS_80.bmp
# ...
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_157.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_45.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_184.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_21.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_62.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_20.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_190.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_212.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_50.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_189.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_193.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_293.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_123.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_72.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_234.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_56.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_289.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_252.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_158.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_51.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_207.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_149.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_294.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_229.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_136.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_17.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_279.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_201.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_145.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_33.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_255.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_228.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_143.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_209.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_131.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_265.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_38.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_180.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_161.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_99.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_160.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_159.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_39.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_70.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_4.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_155.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_135.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_65.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_198.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_219.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_141.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_178.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_144.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_204.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_199.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_80.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_246.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_148.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_249.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_295.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_274.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_191.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_167.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_299.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_27.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_82.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_197.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_216.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_236.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_291.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_53.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_218.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_177.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_206.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_165.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_297.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_205.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_267.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_76.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_124.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_37.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_235.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_154.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_63.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_250.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_272.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_85.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_186.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_97.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_89.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_226.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_25.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_48.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_29.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_78.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_28.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_181.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_81.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_174.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_172.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_132.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_230.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_188.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_271.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_292.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_87.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_296.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_213.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_138.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_54.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_192.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_168.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_24.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_261.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_68.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_253.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_55.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_183.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_152.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_259.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_7.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_16.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_46.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_243.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_241.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_57.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_14.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_133.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_196.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_150.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_277.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_231.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_9.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_244.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_151.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_221.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_42.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_67.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_18.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_125.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_71.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_224.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_2.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_156.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_13.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_6.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_142.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_91.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_95.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_153.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_281.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_223.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_69.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_276.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_147.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_203.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_61.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_74.bmp
# /kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train/Crazing/Cr_30.bmp

# %%
# Load the dataset

train_data_path = '/kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/train'
test_data_path = '/kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/test'
valid_data_path = '/kaggle/input/neu-metal-surface-defects-data/NEU Metal Surface Defects Data/valid'

# Data transformations
data_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize the images to 224x224 (required for ResNet-34)
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize the images
])

train_dataset = datasets.ImageFolder(train_data_path, transform=data_transforms)
test_dataset = datasets.ImageFolder(test_data_path, transform=data_transforms)
valid_dataset = datasets.ImageFolder(valid_data_path, transform=data_transforms)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=64, shuffle=False)

# %%
# Function to plot a grid of images
def imshow_grid(images, labels, classes, rows=4, cols=4):
    fig, axes = plt.subplots(rows, cols, figsize=(10, 10))

    for i, ax in enumerate(axes.flat):
        img = images[i]
        label = labels[i]
        ax.imshow(np.transpose(img, (1, 2, 0)))
        ax.set_title(classes[label])
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# Load a batch of images and labels from the training dataset
sample_loader = iter(train_loader)
images, labels = next(sample_loader)

# Get class names from the dataset
class_names = train_dataset.classes

# Visualize the images
imshow_grid(images, labels, class_names)

# %%
# Initilize resnet34 model
model = resnet34(weights=True)  # Load pre-trained weights

# Replace the last fully connected layer to match your dataset's number of classes
num_classes = len(train_dataset.classes)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, num_classes)

# Move the model to GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
# Train the model
def train_model(model, criterion, optimizer, num_epochs=10):
    train_loss_list = []
    valid_loss_list = []
    train_acc_list = []
    valid_acc_list = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        epoch_loss = running_loss / len(train_loader)
        train_accuracy = correct_train / total_train

        # Validation
        model.eval()
        correct_valid = 0
        total_valid = 0
        running_valid_loss = 0.0

        with torch.no_grad():
            for inputs, labels in valid_loader:
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = model(inputs)
                loss = criterion(outputs, labels)
                running_valid_loss += loss.item()

                _, predicted = torch.max(outputs, 1)
                total_valid += labels.size(0)
                correct_valid += (predicted == labels).sum().item()

        epoch_valid_loss = running_valid_loss / len(valid_loader)
        valid_accuracy = correct_valid / total_valid

        # Record metrics
        train_loss_list.append(epoch_loss)
        valid_loss_list.append(epoch_valid_loss)
        train_acc_list.append(train_accuracy)
        valid_acc_list.append(valid_accuracy)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Valid Loss: {epoch_valid_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Valid Accuracy: {valid_accuracy:.4f}")

    # Plot loss and accuracy curves
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(1, num_epochs + 1), train_loss_list, label='Train')
    plt.plot(range(1, num_epochs + 1), valid_loss_list, label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Loss Curve')

    plt.subplot(1, 2, 2)
    plt.plot(range(1, num_epochs + 1), train_acc_list, label='Train')
    plt.plot(range(1, num_epochs + 1), valid_acc_list, label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Accuracy Curve')

    plt.tight_layout()
    plt.show()

# ... (Code to define the model, criterion, optimizer, and data loaders)

train_model(model, criterion, optimizer, num_epochs=10)
# Out:
# Epoch 1/10, Train Loss: 0.8313, Valid Loss: 0.2557, Train Accuracy: 0.7699, Valid Accuracy: 0.9444
# Epoch 2/10, Train Loss: 0.0952, Valid Loss: 0.0261, Train Accuracy: 0.9879, Valid Accuracy: 1.0000
# Epoch 3/10, Train Loss: 0.0334, Valid Loss: 0.0179, Train Accuracy: 0.9982, Valid Accuracy: 1.0000
# Epoch 4/10, Train Loss: 0.0206, Valid Loss: 0.0107, Train Accuracy: 1.0000, Valid Accuracy: 1.0000
# Epoch 5/10, Train Loss: 0.0171, Valid Loss: 0.0063, Train Accuracy: 1.0000, Valid Accuracy: 1.0000
# Epoch 6/10, Train Loss: 0.0169, Valid Loss: 0.0079, Train Accuracy: 0.9982, Valid Accuracy: 1.0000
# Epoch 7/10, Train Loss: 0.0108, Valid Loss: 0.0056, Train Accuracy: 1.0000, Valid Accuracy: 1.0000
# Epoch 8/10, Train Loss: 0.0086, Valid Loss: 0.0048, Train Accuracy: 1.0000, Valid Accuracy: 1.0000
# Epoch 9/10, Train Loss: 0.0075, Valid Loss: 0.0054, Train Accuracy: 1.0000, Valid Accuracy: 1.0000
# Epoch 10/10, Train Loss: 0.0062, Valid Loss: 0.0060, Train Accuracy: 1.0000, Valid Accuracy: 1.0000

# %%
# Evaluate the model

def evaluate_model(model, data_loader):
    model.eval()
    correct_predictions = 0
    total_samples = 0
    all_predictions = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total_samples += labels.size(0)
            correct_predictions += (predicted == labels).sum().item()

            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = correct_predictions / total_samples
    precision = precision_score(all_labels, all_predictions, average='weighted')
    recall = recall_score(all_labels, all_predictions, average='weighted')
    f1 = f1_score(all_labels, all_predictions, average='weighted')

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

# Evaluate on test set
evaluate_model(model, test_loader)
# Out:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
